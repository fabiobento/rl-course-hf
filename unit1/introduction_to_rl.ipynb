# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/fabiobento/rl-course-hf/blob/main/unit1/introduction_to_rl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/fabiobento/rl-course-hf/blob/main/unit1/introduction_to_rl.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# Adaptado do [Hugging Face Deep Reinforcement Learning Course](https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt)

# %% [markdown]
# # Introdução ao Aprendizado por Reforço

# %% [markdown]
# ## O que é Aprendizado por Reforço?

# %% [markdown]
# Para entender o Aprendizado por Reforço (Reinforcement Learning), vamos começar com a visão geral.

# %% [markdown]
# ### A visão geral

# %% [markdown]
# A ideia por trás do Aprendizado por Reforço(*Reinforcement Learning* — RL) é que um agente (uma IA) aprenderá com o ambiente ao **interagir** com ele (por tentativa e erro) e receber **recompensas**(_rewards_) negativas ou positivas como feedback por realizar _actions_.
#
# Aprender a partir das interações com o ambiente **vem das nossas experiências naturais**.
#
#
# Por exemplo, imagine colocar alguém em frente a um videogame que ele nunca jogou, entregar um controle e deixá-lo sozinho.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/Illustration_1.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# A pessoa irá interagir com o ambiente (o videogame) pressionando o direcional pra direita (ação).
#
# Ela pegou uma moeda, isso é uma recompensa de +1.
# - É positivo, ela acabou de entender que neste jogo **deve pegar as moedas**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/Illustration_2.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Mas então, **ele aperta o direcional pra direita novamente** e encosta em um inimigo.
# - Ele acabou de morrer, então isso é uma recompensa de -1.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/Illustration_3.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Ao interagir com o ambiente por tentativa e erro, o jogador entende que:
# - **precisa pegar as moedas nesse ambiente, mas evitar os inimigos.**

# %% [markdown]
# É assim que humanos e animais aprendem, **por meio da interação**.
#
# > O Aprendizado por Reforço é apenas uma **abordagem computacional de aprender a partir das _actions_**.

# %% [markdown]
# ### Uma definição mais formal

# %% [markdown]
# Podemos agora fazer uma definição mais formal do Aprendizado por Reforço:
#
# > O aprendizado por reforço é um *framework* para resolver tarefas de controle (também chamadas de problemas de decisão) por meio da criação de agentes que aprendem com o ambiente interagindo com ele por meio de tentativa e erro e recebendo _rewards_ (positivas ou negativas) como feedback exclusivo.

# %% [markdown]
# Mas, como o Aprendizado por Reforço Funciona?

# %% [markdown]
# ## O Framework do Aprendizado por Reforço

# %% [markdown]
# ### O processo RL

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/RL_process.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# O processo RL: um loop de state, action, reward e próximo state.
#
# Fonte: <a href="http://incompleteideas.net/book/RLbook2020.pdf" target="_blank">Reinforcement Learning: An Introduction, Richard Sutton and Andrew G. Barto</a>
# </span>

# %% [markdown]
# Para entender o processo RL, vamos imaginar um agente aprendendo a jogar um jogo de plataforma:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/RL_process_game.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# - Nosso Agente recebe o **`state`** $S_0$ do **`Environment`** — recebemos o primeiro frame de nosso jogo (o `Environment`).
# - Com base no **`state`** $S_0$, o agente executa a **`action`** $A_0$ — nosso agente se move para a direita.
# - O ambiente vai a para um novo **`state`** $S_1$ — novo frame.
# - O ambiente dá uma **reward** $R_1$ para o agente — não estamos mortos (*Positive Reward* $+1$).

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/sars.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Esse loop retorna uma sequência state, action, reward, next state.
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# O objetivo do agente é **maximizar** a recompensa acumulativa(**_cumulative reward_**), chamada de retorno esperado(**_expected return_**).

# %% [markdown]
# ### A hipótese da recompensa(_reward hypothesis_): a ideia central do Aprendizado por Reforço

# %% [markdown]
# > Por que o objetivo do agente é maximizar o retorno esperado?
#
# Porque a RL se baseia na **_reward hypothesis_**, ou seja, todas as metas podem ser descritas como a **maximização do retorno esperado** (_expected cumulative reward_).
#
# É por isso que, no Aprendizado por Reforço, **para ter o melhor comportamento**(_best behavior_), nosso objetivo é aprender a realizar _actions_ que **maximizem a _expected cumulative reward_**.

# %% [markdown]
# ### A propriedade de Markov

# %% [markdown]
# Em artigos, você verá que o processo de RL é chamado de **Processo de Decisão de Markov** (*Markov Decision Process* — MDP).
#
# Voltaremos a falar sobre a propriedade de Markov nas próximas unidades.
# Mas se você precisa se lembrar de algo hoje sobre isso, é o seguinte:
# > a Propriedade de Markov implica que nosso agente precisa **apenas do _state_ atual para decidir** qual _action_ tomar e **não do histórico de todos os _states_ e _actions_** que ele tomou antes.

# %% [markdown]
# ### _Observations/States Space_

# %% [markdown]
# _Observations/State_ são as **informações que nosso agente obtém do ambiente**.
#
# No caso de um videogame, pode ser um frame (uma captura de tela).
#
# No caso de agente de *trading*, pode ser o valor de uma determinada _action_, etc.

# %% [markdown]
# No entanto, é preciso fazer uma diferenciação entre *_observation_* e *_state_*:

# %% [markdown]
# - State: é **uma descrição completa do _state_ do mundo** (não há informações ocultas). Em um ambiente totalmente observado.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/chess.jpg" alt="The RL process" width="100%">
#
#
# <span style="font-size:80%">
# No jogo de xadrez, recebemos um state do ambiente, pois temos acesso a todas as informações do tabuleiro de xadrez.
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Em um jogo de xadrez, temos acesso a todas as informações do tabuleiro, portanto, recebemos um _state_ do ambiente.
#
# Em outras palavras, o ambiente é totalmente observado.

# %% [markdown]
# - _Observation_: é uma **descrição parcial do _state_**, em um ambiente parcialmente observado.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/mario.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Em Super Mario Bros, só vemos a parte do nível próximo ao jogador, portanto, recebemos uma observation.
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Em Super Mario Bros, estamos em um ambiente parcialmente observado.
#
# Recebemos uma _observation_, **pois vemos apenas uma parte do nível**.

# %% [markdown]
# > Neste curso, usamos o termo “_state_" para designar tanto o _state_ quanto a observação, mas fique atento, pois faremos a distinção nas implementações.

# %% [markdown]
# Para recaptular:
#
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/obs_space_recap.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ### _Action Space_

# %% [markdown]
# _Action space_ é o conjunto de **todas as possíveis _actions_ em um ambiente**.

# %% [markdown]
# As _actions_ podem vir de um espaço **discreto** ou **contínuo**:

# %% [markdown]
# - *Espaço discreto*: a quantidade de possíveis _actions_ é **finita**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/mario.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Em Super Mario Bros, temos apenas quatro actions possíveis: esquerda, direita, para cima (pular) e para baixo (agachar).
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# - Espaço contínuo: a quantidade de possíveis _actions_ é **infinita**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/self_driving_car.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Um agente de carro autônomo tem um número infinito de actions possíveis, pois pode virar à esquerda 20°, 21,1°, 21,2°, buzinar, virar à direita 20°...
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Para recaptular
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/action_space.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Levar essas informações de _observation space_ e _action space_ em consideração é muito importante, pois elas **serão importantes na escolha do algoritmo de RL**.

# %% [markdown]
# ### _Reward_ e _discounting_

# %% [markdown]
# A _reward_ é fundamental na RL porque é **o único feedback** para o agente.
#
# Graças a ela, nosso agente sabe **se a _action_ realizada foi boa ou não**.

# %% [markdown]
# A _cumulative reward_ em cada passo de tempo $t$ pode ser escrita como:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/rewards_1.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>
#
#
# > A _cumulative reward_ é igual à soma de todas as _rewards_ da sequência.

# %% [markdown]
# O que é equivalent a:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/rewards_2.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# No entanto, na realidade, **não podemos simplesmente adicioná-las dessa forma**.
#
# As _rewards_ que chegam mais cedo (no início do jogo) **têm mais probabilidade de acontecer**, pois são mais previsíveis do que a _reward_ futura de longo prazo.

# %% [markdown]
# Vamos supor que seu agente é esse rato que pode se mover um bloco por vez, e seu oponente é o gato (que também pode se mover).
#
# O objetivo do rato é **comer a maior quantidade de queijo possível antes de ser pego pelo gato**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/rewards_3.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Como podemos ver no diagrama, **é mais provável comer o queijo que está perto de nós do que o queijo próximo ao gato** (quanto mais perto estamos do gato, mais perigoso é).
#
# Consequentemente, **a _reward_ próxima ao gato, mesmo que seja maior (mais queijo), será mais descontada**, já que não temos certeza se conseguiremos comê-la.

# %% [markdown]
# Para descontar as _rewards_, fazemos assim:
# 1. Definimos uma taxa de desconto chamada gamma($\gamma$). **Ela deve estar entre $0$ e $1$**. Na maioria das vezes, entre **$0,95$ e $0,99$**.
# - Quanto maior o $\gamma$, menor o desconto. Isso significa que nosso agente **se importa mais com a _reward_ de longo prazo**.
# - Por outro lado, quanto menor o $\gamma$, maior o desconto. Isso significa que nosso **agente se importa mais com a _reward_ de curto prazo (o queijo mais próximo)**.

# %% [markdown]
# 2. Então, cada _reward_ será descontada por $\gamma$ elevado ao expoente do passo de tempo. À medida que o passo de tempo aumenta, o gato se aproxima de nós, então a _reward_ futura é cada vez menos provável de acontecer.
#
# Nossa _reward_ acumulada esperada descontada é:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/rewards_4.jpg" alt="The RL process" width="100%">
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ## Tipos de tarefas

# %% [markdown]
# Uma tarefa é uma **instância** de um problema de RL.
#
# Podemos ter dois tipos de tarefas:
# - **episódicas** e,
# - **contínuas**

# %% [markdown]
# ### Tarefa Episódica (_Episodic Task_)

# %% [markdown]
# Neste caso, temos um ponto de início e um ponto de término **(_terminal state_)**.
#
# **Isso cria um episódio**: uma lista de _States_, _Actions_, _Rewards_ e novos _States_.
#
# Por exemplo, pense no Super Mario Bros: um episódio começa ao iniciar um novo nível do Mario e termina **quando você é derrotado ou chega ao final do nível**.

# %% [markdown]
# O começo de um novo episódio
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/mario.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ### Tarefa Contínua (_Continuing Task_)

# %% [markdown]
# Essas são tarefas que continuam para sempre (**sem _terminal state_**).
#
# Nesse caso, o agente precisa **aprender a escolher as melhores _actions_ e, ao mesmo tempo, interagir com o ambiente**.

# %% [markdown]
# Por exemplo, um agente que faz negociação automatizada de ações da bolsa de valores.
# - Para essa tarefa, não há ponto inicial e _terminal state_.
# - **O agente continua em execução até que decidamos interrompê-lo**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/stock.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Para recapitular:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/tasks.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ## O trade-off de Exploration/Exploitation

# %% [markdown]
# Por fim, antes de analisar os diferentes métodos para resolver problemas de RL, precisamos abordar mais um tópico muito importante: o *trade-off de exploration/exploitation*.

# %% [markdown]
# - *Exploration* é explorar o ambiente tentando _actions_ aleatórias para **encontrar mais informações sobre o ambiente**.
# - *Explotation* é o **aproveitamento de informações conhecidas para maximizar a _reward_**.

# %% [markdown]
# Lembre-se de que o objetivo do nosso agente de RL é maximizar a _reward_ cumulativa esperada.
#
# No entanto, **podemos cair em uma armadilha comum**.
#
# Vamos ver um exemplo:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/exp_1.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Nesse jogo, nosso camundongo pode ter uma **quantidade infinita de queijos pequenos** (+1 cada). Mas, no topo do labirinto, há uma soma gigantesca de queijo (+1000).

# %% [markdown]
# No entanto, se nos concentrarmos apenas em *explotation*, nosso agente nunca alcançará a gigantesca soma de queijo.
#
# Em vez disso, ele só aproveitará **a fonte de _rewards_ mais próxima**, mesmo que essa fonte seja pequena.

# %% [markdown]
# Mas se nosso agente explorar um pouco, ele poderá **descobrir a grande _reward_** (a pilha de queijo grande).

# %% [markdown]
# Isso é o que chamamos de trade-off exploration/explotation. Precisamos equilibrar o quanto **exploramos o ambiente** e o quanto **aproveitamos o que sabemos sobre ele**.

# %% [markdown]
# Portanto, precisamos **definir uma regra que ajude a lidar com esse trade-off**. Veremos as diferentes maneiras de lidar com isso nas próximas unidades.

# %% [markdown]
# Se isso ainda for confuso, **pense em um problema real: a escolha de um restaurante**:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/exp_2.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://inst.eecs.berkeley.edu/~cs188/sp20/assets/lecture/lec15_6up.pdf" target="_blank">Berkeley AI Course</a>
# </span>

# %% [markdown]
# - *Explotation*: Você vai ao mesmo restaurante que sabe que é bom todos os dias e **corre o risco de perder outro restaurante melhor**.
# - *Exploration*: Experimente restaurantes que nunca visitou antes, com o risco de ter uma experiência ruim, **mas com a provável oportunidade de ter uma experiência fantástica**.

# %% [markdown]
# Para recapitular:
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/expexpltradeoff.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ## As duas principais abordagens para resolver problemas de RL

# %% [markdown]
# > Agora que aprendemos o framework, como resolvemos o problema de RL?

# %% [markdown]
# Em outras palavras, como criamos um agente de RL que pode **selecionar as _actions_ que maximizam sua _expected cumulative reward_**?

# %% [markdown]
# ### A _Policy_ $\pi$: o cérebro do agente

# %% [markdown]
# A _Policy_ $\pi$ é o **cérebro do nosso Agente**, é a função que nos diz **qual _action_ executar dado o estado em que nos encontramos**. Portanto, ela define o **comportamento do agente** em um determinado momento.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/policy_1.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Pense na policy como o cérebro do nosso agente, a função que nos dirá a action a ser tomada em um determinado state
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Essa _policy_ **é a função que queremos aprender**:
# - Nosso objetivo é encontrar a **_optimal policy_ $\pi$**: a _policy_ que **maximiza o retorno esperado** quando o agente age de acordo com ela.
# - Encontramos essa $\pi$*   **por meio de treinamento**.

# %% [markdown]
# Há duas abordagens para treinar nosso agente a encontrar essa _optimal policy_  $\pi$*:
# - **Diretamente**, ensinando o agente a aprender **qual _action_ executar**, dado o _state_ atual: (_Policy-Based Methods_).
# - Indiretamente, **ensinar o agente a aprender qual _state_ é mais valioso** e, em seguida, executar a _action_ que **leva aos _states_ mais valiosos**: **Métodos baseados em valor**(_Value-Based Methods_).

# %% [markdown]
# #### _Policy-Based Methods_

# %% [markdown]
# Em métodos baseados em _policy_ , aprendemos uma _policy function_ diretamente.

# %% [markdown]
# Essa função definirá um mapeamento de cada _state_ para a melhor _action_ correspondente.
#
# Uma outra opção é ela  definir uma **distribuição de probabilidade sobre o conjunto de possíveis _actions_ naquele _state_**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/policy_2.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Como podemos ver aqui, a deterministic policy indica diretamente a action a ser tomada em cada passo.
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Então temos dois tipos de _policies_:
# - _Determinística_: Uma _policy_ em um dado _state_ **sempre retornará a mesma _action_**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/policy_3.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# action=policy(state).
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/policy_4.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# action=policy(state)
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# - Estocástica: gera **uma distribuição de probabilidade sobre as _actions_**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/policy_5.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# policy(actions | state) = distribuição de probabilidade sobre o conjunto de _actions_ dado o _state_ atual
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/policy-based.png" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Dado um estado inicial, nossa _stochastic policy_ produzirá distribuições de probabilidade sobre as ações possíveis nesse um estado.
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Recaptulando:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/pbm_1.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/pbm_2.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# #### _Value-Based Methods_

# %% [markdown]
# Nos _value-based methods_ em vez de **aprender uma policy function**, aprendemos uma _value function_ que mapeia um _state_ ao **valor esperado(_expected value_) de estar naquele _state_**.

# %% [markdown]
# O valor de um _state_ é o **_expected discounted return_** que o agente pode obter se ele **começar nesse _state_, e então agir de acordo com nossa _policy_**.

# %% [markdown]
# "Agir de acordo com nossa _policy_" significa que a nossa _policy_ é **"ir para o  _state_ de maior valor"**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/value_1.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Aqui vemos que a nossa _value function_ **definiu valores para cada possível _state_**.

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/value_2.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
# Graças à nossa value function, a cada passo nossa policy selecionará o state com o maior valor definido pela value function: -7, depois -6, depois -5 (e assim por diante) até atingir o objetivo.
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# Recapitulando:

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/vbm_1.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/vbm_2.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ## O "Deep" no _Deep Reinforcement Learning_

# %% [markdown]
# O que discutimos até agora é _Reinforcement Learning_.
#
# > Mas e o "Deep"?

# %% [markdown]
# O Aprendizado por Reforço Profundo(_Deep Reinforcement Learning_-Deep RL) utiliza **redes neurais profundas (_deep neural networks_) para resolver problemas de RL**- daí vem o nome "deep".

# %% [markdown]
# Por exemplo, na próxima unidade, vamos aprender sobre dois algoritmos _value-based_:
# - _Q-learning_ (RL clássico) e
# - _Deep Q-Learning_

# %% [markdown]
# Você verá que a diferença é que, na primeira abordagem, **utilizamos um algoritmo tradicional** para criar a _Q table_ que nos ajuda a encontrar que _action_ executar em cada _state_.

# %% [markdown]
# Na segunda abordagem, **utilizamos uma rede neural**(_neural network_) para aproximar o _Q value_)

# %% [markdown]
# <img src="https://github.com/fabiobento/rl-course-hf/raw/main/unit1/images/deep.jpg" alt="The RL process" width="100%">
#
# <span style="font-size:80%">
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# ## Sumário

# %% [markdown]
# Muita informação, né? Então vamos resumir:

# %% [markdown]
# - A aprendizagem por reforço (_Reinforcemente Learning_ - RL) é uma abordagem computacional de aprendizagem a partir de ações. Criamos um agente que aprende com o ambiente, interagindo com ele **por meio de tentativa e erro** e recebendo recompensas (negativas ou positivas) como feedback.
#
# - O objetivo de qualquer agente de RL é maximizar sua recompensa cumulativa esperada (_expected cumulative reward_ ou _expected return_), pois a RL se baseia na hipótese da recompensa (**_reward hypothesis_**), que é que **todos os objetivos podem ser descritos como a maximização da recompensa cumulativa esperada**.
#
# - O processo de RL é um loop que gera uma sequência de estado, ação, recompensa e próximo estado(**_state, action, reward, next state_**).
#
# - Para calcular a recompensa cumulativa esperada, descontamos as recompensas: as recompensas que vêm mais cedo (no início do jogo) **são mais prováveis de acontecer, pois são mais previsíveis do que a recompensa futura a longo prazo**.
#
# - Para resolver um problema de RL, você deseja **encontrar uma _optimal policy_**. A **policy** é o “cérebro” do seu agente, que nos dirá **qual ação tomar em um determinado estado**. A _optimal policy_ é aquela que **fornece as ações que maximizam o _expected return_**.
#
# - Existem duas maneiras de encontrar sua _optimal policy_:
#
#     1. Treinando sua _policy_ diretamente: **_policy-based methods_**.
#     2. Treinando uma _function value_ que nos diz o _expected return_ que o agente obterá em cada estado e usando essa função para definir nossa _policy_: **_value-based methods_**.
# - Por fim, falamos sobre Deep RL  porque introduzimos **redes neurais profundas para estimar a ação a ser tomada (_policy-based_) ou para estimar o valor de um estado (_value-based_)**, daí o nome “profundo”.

# %% [markdown]
# ### Glossário

# %% [markdown]
# <span style="font-size:80%">
# Traduzido do glossário criado por : <a href="https://github.com/lucifermorningstar1305" target="_blank">@lucifermorningstar1305</a>, <a href="https://github.com/daspartho" target="_blank">@daspartho</a>
# , <a href="https://github.com/misza222" target="_blank">@misza222</a>
#
# Fonte: <a href="https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt" target="_blank">Hugging Face Deep Reinforcement Learning Course</a>
# </span>

# %% [markdown]
# #### Agent:
# - Um agente aprende a **tomar decisões por tentativa e erro, com recompensas e punições do ambiente**.
#
# #### Environment:
# - O ambiente é um mundo simulado **onde um agente pode aprender interagindo com ele**.
#
# #### Markov Property:
# - Isso implica que a ação tomada pelo nosso agente é **condicional apenas ao estado presente e independente dos estados e ações passados**.
#
# #### Observations/State:
# - **State**: Descrição completa do estado do mundo.
# - **Observation**: Descrição parcial do estado do ambiente/mundo.
#
# #### Actions:
# - **Discrete Actions**: Número finito de ações, como esquerda, direita, cima e baixo.
# - **Continuous Actions**: Possibilidade infinita de ações; por exemplo, no caso dos carros autônomos, o cenário de direção tem uma possibilidade infinita de ações ocorrendo.
#
# #### Rewards and Discounting:
# - **Rewards**: Fator fundamental em RL. Indica ao agente se a ação realizada é boa ou ruim. Os algoritmos RL estão focados em maximizar a recompensa acumulada(**_cumulative rewards_**).
# - **Reward Hypothesis**: Os problemas de RL podem ser formulados como uma maximização do retorno cumulativo.
# - **Discounting** é realizado porque as recompensas obtidas no início são mais prováveis de acontecer, pois são mais previsíveis do que as recompensas a longo prazo..
#
# #### Tasks:
# - **Episodic**: Tem um ponto inicial e um ponto final.
# - **Continuous**: Tem um ponto inicial mas não tem ponto final.
#
# #### Exploration v/s Exploitation Trade-Off
# - **Exploration**: Trata-se de explorar o ambiente, tentando ações aleatórias e recebendo feedback/retornos/recompensas do ambiente.
# - **Exploitation**: Trata-se de explorar o que sabemos sobre o meio ambiente para obter o máximo de recompensas.
# - **Exploration-Exploitation Trade-Off**: Equilibra o quanto queremos **explorar o meio ambiente** e o quanto queremos **explorar o que sabemos sobre ele**.
#
# #### Policy
# - **Policy**: É chamado de cérebro do agente. Ele nos diz quais ações tomar, dada a situação.
# - **Optimal Policy**: Política que maximiza o retorno esperado quando um agente age de acordo com ela. É aprendida por meio de treinamento.
#
# #### Policy-based Methods:
# - Uma abordagem para resolver problemas de RL.
# - Neste método, a Policy é aprendida diretamente.
# - Mapeia cada estado para a melhor ação correspondente nesse estado; ou oma distribuição de probabilidade sobre o conjunto de ações possíveis nesse estado.
#
# #### Value-based Methods:
# - Outra abordagem para resolver problemas de RL.
# - Aqui, em vez de treinar uma policy, treinamos uma função de valor(**_value function_**) que mapeia cada estado para o valor esperado de estar nesse estado.
