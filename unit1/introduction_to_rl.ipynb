# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/fabiobento/rl-course-hf/blob/main/unit1/unit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/fabiobento/rl-course-hf/blob/main/unit1/unit1.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# Adaptado do [repositório](https://github.com/huggingface/deep-rl-class) do [Hugging Face Deep Reinforcement Learning Course](https://huggingface.co/learn/deep-rl-course/unit0/introduction?fw=pt)

# %% [markdown]
# # Unit 1: Train your first Deep Reinforcement Learning Agent 🤖
#
#
# In this notebook, you'll train your **first Deep Reinforcement Learning agent** a Lunar Lander agent that will learn to **land correctly on the Moon 🌕**. Using [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) a Deep Reinforcement Learning library, share them with the community, and experiment with different configurations
#
# ⬇️ Here is an example of what **you will achieve in just a couple of minutes.** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - [LunarLander-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ### The library used 📚
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## A small recap of Deep Reinforcement Learning 📚
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# Let's do a small recap on what we learned in the first Unit:
#
# - Reinforcement Learning is a **computational approach to learning from actions**. We build an agent that learns from the environment by **interacting with it through trial and error** and receiving rewards (negative or positive) as feedback.
#
# - The goal of any RL agent is to **maximize its expected cumulative reward** (also called expected return) because RL is based on the _reward hypothesis_, which is that all goals can be described as the maximization of an expected cumulative reward.
#
# - The RL process is a **loop that outputs a sequence of state, action, reward, and next state**.
#
# - To calculate the expected cumulative reward (expected return), **we discount the rewards**: the rewards that come sooner (at the beginning of the game) are more probable to happen since they are more predictable than the long-term future reward.
#
# - To solve an RL problem, you want to **find an optimal policy**; the policy is the "brain" of your AI that will tell us what action to take given a state. The optimal one is the one that gives you the actions that max the expected return.
#
# There are **two** ways to find your optimal policy:
#
# - By **training your policy directly**: policy-based methods.
# - By **training a value function** that tells us the expected return the agent will get at each state and use this function to define our policy: value-based methods.
#
# - Finally, we spoke about Deep RL because **we introduce deep neural networks to estimate the action to take (policy-based) or to estimate the value of a state (value-based) hence the name "deep."**

# %% [markdown]
# ## Install dependencies and create a virtual screen 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones.
#
# - `gymnasium[box2d]`: Contains the LunarLander-v2 environment 🌛
# - `stable-baselines3[extra]`: The deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
#
# To make things easier, we created a script to install all these dependencies.

# %%
# %pip install huggingface_sb3
# %pip install swig
# %pip install "gymnasium[box2d]"
# %pip install stable-baselines3==2.0.0a5

# %% [markdown]
# ## Import the packages 📦
#
# One additional library we import is huggingface_hub **to be able to upload and download trained models from the hub**.
#
#
# The Hugging Face Hub 🤗 works as a central place where anyone can share and explore models and datasets. It has versioning, metrics, visualizations and other features that will allow you to easily collaborate with others.
#
# You can see here all the Deep reinforcement Learning models available here👉 https://huggingface.co/models?pipeline_tag=reinforcement-learning&sort=downloads

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# ## Understand Gymnasium and how it works 🤖
#
# 🏋 The library containing our environment is called Gymnasium.
# **You'll use Gymnasium a lot in Deep Reinforcement Learning.**
#
# Gymnasium is the **new version of Gym library** [maintained by the Farama Foundation](https://farama.org/).
#
# The Gymnasium library provides two things:
#
# - An interface that allows you to **create RL environments**.
# - A **collection of environments** (gym-control, atari, box2D...).
#
# Let's look at an example, but first let's recall the RL loop.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# At each step:
# - Our Agent receives a **state (S0)** from the **Environment** — we receive the first frame of our game (Environment).
# - Based on that **state (S0),** the Agent takes an **action (A0)** — our Agent will move to the right.
# - The environment transitions to a **new** **state (S1)** — new frame.
# - The environment gives some **reward (R1)** to the Agent — we’re not dead *(Positive Reward +1)*.
#
#
# With Gymnasium:
#
# 1️⃣ We create our environment using `gymnasium.make()`
#
# 2️⃣ We reset the environment to its initial state with `observation = env.reset()`
#
# At each step:
#
# 3️⃣ Get an action using our model (in our example we take a random action)
#
# 4️⃣ Using `env.step(action)`, we perform this action in the environment and get
# - `observation`: The new state (st+1)
# - `reward`: The reward we get after executing the action
# - `terminated`: Indicates if the episode terminated (agent reach the terminal state)
# - `truncated`: Introduced with this new version, it indicates a timelimit or if an agent go out of bounds of the environment for instance.
# - `info`: A dictionary that provides additional information (depends on the environment).
#
# For more explanations check this 👉 https://gymnasium.farama.org/api/env/#gymnasium.Env.step
#
# If the episode is terminated:
# - We reset the environment to its initial state with `observation = env.reset()`
#
# **Let's look at an example!** Make sure to read the code

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v3")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 2
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 2

# %% [markdown]
# ## Create the LunarLander environment 🌛 and understand how it works
#
# ### [The environment 🎮](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# In this first tutorial, we’re going to train our agent, a [Lunar Lander](https://gymnasium.farama.org/environments/box2d/lunar_lander/), **to land correctly on the moon**. To do that, the agent needs to learn **to adapt its speed and position (horizontal, vertical, and angular) to land correctly.**
#
# ---
#
#
# 💡 A good habit when you start to use an environment is to check its documentation
#
# 👉 https://gymnasium.farama.org/environments/box2d/lunar_lander/
#
# ---

# %% [markdown]
# Let's see what the Environment looks like:

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v3")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [76.289856    0.6498131   4.011606    1.8750228   0.27548045  4.888693
#   0.8721451   0.97928953]

# %% [markdown]
# We see with `Observation Space Shape (8,)` that the observation is a vector of size 8, where each value contains different information about the lander:
# - Horizontal pad coordinate (x)
# - Vertical pad coordinate (y)
# - Horizontal speed (x)
# - Vertical speed (y)
# - Angle
# - Angular speed
# - If the left leg contact point has touched the land (boolean)
# - If the right leg contact point has touched the land (boolean)

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 3

# %% [markdown]
# The action space (the set of possible actions the agent can take) is discrete with 4 actions available 🎮:
#
# - Action 0: Do nothing,
# - Action 1: Fire left orientation engine,
# - Action 2: Fire the main engine,
# - Action 3: Fire right orientation engine.
#
# Reward function (the function that will give a reward at each timestep) 💰:
#
# After every step a reward is granted. The total reward of an episode is the **sum of the rewards for all the steps within that episode**.
#
# For each step, the reward:
#
# - Is increased/decreased the closer/further the lander is to the landing pad.
# -  Is increased/decreased the slower/faster the lander is moving.
# - Is decreased the more the lander is tilted (angle not horizontal).
# - Is increased by 10 points for each leg that is in contact with the ground.
# - Is decreased by 0.03 points each frame a side engine is firing.
# - Is decreased by 0.3 points each frame the main engine is firing.
#
# The episode receive an **additional reward of -100 or +100 points for crashing or landing safely respectively.**
#
# An episode is **considered a solution if it scores at least 200 points.**

# %% [markdown]
# #### Vectorized Environment
#
# - We create a vectorized environment (a method for stacking multiple independent environments into a single environment) of 16 environments, this way, **we'll have more diverse experiences during the training.**

# %%
# Create the environment
env = make_vec_env('LunarLander-v3', n_envs=16)

# %% [markdown]
# ## Create the Model 🤖
# - We have studied our environment and we understood the problem: **being able to land the Lunar Lander to the Landing Pad correctly by controlling left, right and main orientation engine**. Now let's build the algorithm we're going to use to solve this Problem 🚀.
#
# - To do so, we're going to use our first Deep RL library, [Stable Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/).
#
# - SB3 is a set of **reliable implementations of reinforcement learning algorithms in PyTorch**.
#
# ---
#
# 💡 A good habit when using a new library is to dive first on the documentation: https://stable-baselines3.readthedocs.io/en/master/ and then try some tutorials.
#
# ----

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/sb3.png" alt="Stable Baselines3">

# %% [markdown]
# To solve this problem, we're going to use SB3 **PPO**. [PPO (aka Proximal Policy Optimization) is one of the SOTA (state of the art) Deep Reinforcement Learning algorithms that you'll study during this course](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#example%5D).
#
# PPO is a combination of:
# - *Value-based reinforcement learning method*: learning an action-value function that will tell us the **most valuable action to take given a state and action**.
# - *Policy-based reinforcement learning method*: learning a policy that will **give us a probability distribution over actions**.

# %% [markdown]
# Stable-Baselines3 is easy to set up:
#
# 1️⃣ You **create your environment** (in our case it was done above)
#
# 2️⃣ You define the **model you want to use and instantiate this model** `model = PPO("MlpPolicy")`
#
# 3️⃣ You **train the agent** with `model.learn` and define the number of training timesteps
#
# ```
# # Create environment
# env = gym.make('LunarLander-v2')
#
# # Instantiate the agent
# model = PPO('MlpPolicy', env, verbose=1)
# # Train the agent
# model.learn(total_timesteps=int(2e5))
# ```

# %%
# SOLUTION
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device
# /home/fabio/anaconda3/envs/dnn-25.1/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   # Switch to eval mode (this affects batch norm / dropout)

# %% [markdown]
# ## Train the PPO agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~20min, but you can use fewer timesteps if you just want to try it out.
# - During the training, take a ☕ break you deserved it 🤗

# %% [markdown]
# #### Solution

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.4     |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    fps             | 7681     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 5123        |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007039817 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000674   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 4.93e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.8         |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 4834         |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0046906522 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 8.04e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 583          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 2.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 4696         |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0073183146 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00169     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 329          |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00661     |
# |    value_loss           | 1.15e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 4605        |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007180918 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000537   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 420         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 959         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.5        |
# |    ep_rew_mean          | -97.6       |
# | time/                   |             |
# |    fps                  | 4551        |
# |    iterations           | 6           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008556262 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0782     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 402         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 702         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.8         |
# |    ep_rew_mean          | -92          |
# | time/                   |              |
# |    fps                  | 4511         |
# |    iterations           | 7            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0068860594 |
# |    clip_fraction        | 0.0861       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.00176      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 395          |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 594          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.7        |
# |    ep_rew_mean          | -67.7       |
# | time/                   |             |
# |    fps                  | 4494        |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009302394 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 450         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -48.9       |
# | time/                   |             |
# |    fps                  | 4461        |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.008163402 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -1.41e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 386         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | -36.7        |
# | time/                   |              |
# |    fps                  | 4376         |
# |    iterations           | 10           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0076156044 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 6.12e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 415          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 427          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -25         |
# | time/                   |             |
# |    fps                  | 4358        |
# |    iterations           | 11          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.009021187 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.00721     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 175         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 399         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 147        |
# |    ep_rew_mean          | -16.9      |
# | time/                   |            |
# |    fps                  | 4218       |
# |    iterations           | 12         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.00913051 |
# |    clip_fraction        | 0.0749     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | -0.000261  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 271        |
# |    n_updates            | 44         |
# |    policy_gradient_loss | -0.005     |
# |    value_loss           | 516        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | -17.8        |
# | time/                   |              |
# |    fps                  | 4033         |
# |    iterations           | 13           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0043893675 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.00203     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 368          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 606          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -6.74       |
# | time/                   |             |
# |    fps                  | 3804        |
# |    iterations           | 14          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.005184798 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.000346   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 320         |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 632         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -4.77        |
# | time/                   |              |
# |    fps                  | 3539         |
# |    iterations           | 15           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0050791907 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.00603     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 335          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 580          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 322       |
# |    ep_rew_mean          | -0.531    |
# | time/                   |           |
# |    fps                  | 3358      |
# |    iterations           | 16        |
# |    time_elapsed         | 78        |
# |    total_timesteps      | 262144    |
# | train/                  |           |
# |    approx_kl            | 0.0070585 |
# |    clip_fraction        | 0.0207    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.2      |
# |    explained_variance   | 0.0866    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 166       |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.00294  |
# |    value_loss           | 495       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | -0.136      |
# | time/                   |             |
# |    fps                  | 3110        |
# |    iterations           | 17          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005383346 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 487         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 456         |
# |    ep_rew_mean          | 2.16        |
# | time/                   |             |
# |    fps                  | 2922        |
# |    iterations           | 18          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.004423558 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 230         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 357         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 536         |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 2786        |
# |    iterations           | 19          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.005457552 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.7        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 239         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 615          |
# |    ep_rew_mean          | 24.9         |
# | time/                   |              |
# |    fps                  | 2679         |
# |    iterations           | 20           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0046077077 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.000876    |
# |    value_loss           | 167          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 666         |
# |    ep_rew_mean          | 42          |
# | time/                   |             |
# |    fps                  | 2578        |
# |    iterations           | 21          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.004350449 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000742   |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 688         |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 2514        |
# |    iterations           | 22          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.009123953 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 726         |
# |    ep_rew_mean          | 60.4        |
# | time/                   |             |
# |    fps                  | 2437        |
# |    iterations           | 23          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.008149605 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.9        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 756          |
# |    ep_rew_mean          | 70.7         |
# | time/                   |              |
# |    fps                  | 2392         |
# |    iterations           | 24           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0035184417 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 75.5         |
# | time/                   |              |
# |    fps                  | 2355         |
# |    iterations           | 25           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0060429242 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72           |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 104          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 776        |
# |    ep_rew_mean          | 80.9       |
# | time/                   |            |
# |    fps                  | 2314       |
# |    iterations           | 26         |
# |    time_elapsed         | 184        |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.00520134 |
# |    clip_fraction        | 0.0482     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 67.6       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00106   |
# |    value_loss           | 145        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 789         |
# |    ep_rew_mean          | 83.2        |
# | time/                   |             |
# |    fps                  | 2276        |
# |    iterations           | 27          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005123106 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 83.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 794         |
# |    ep_rew_mean          | 90.6        |
# | time/                   |             |
# |    fps                  | 2250        |
# |    iterations           | 28          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.003190194 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.000683   |
# |    value_loss           | 62.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 811          |
# |    ep_rew_mean          | 97.8         |
# | time/                   |              |
# |    fps                  | 2218         |
# |    iterations           | 29           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0051165307 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.04         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 54.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 846          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 2192         |
# |    iterations           | 30           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0054012937 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00091     |
# |    value_loss           | 49.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 850         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 2171        |
# |    iterations           | 31          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004910075 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000515   |
# |    value_loss           | 67.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 2150         |
# |    iterations           | 32           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0047224956 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.1         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00059     |
# |    value_loss           | 94.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 850          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 2121         |
# |    iterations           | 33           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0037777415 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 98.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 858         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 2098        |
# |    iterations           | 34          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.004479026 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 25.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 875         |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 2077        |
# |    iterations           | 35          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.004951994 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.75        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 31.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 902        |
# |    ep_rew_mean          | 116        |
# | time/                   |            |
# |    fps                  | 2054       |
# |    iterations           | 36         |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 589824     |
# | train/                  |            |
# |    approx_kl            | 0.00386866 |
# |    clip_fraction        | 0.0344     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.5       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.000678  |
# |    value_loss           | 49.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 941          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 37           |
# |    time_elapsed         | 298          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0043517333 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.49         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000126    |
# |    value_loss           | 10.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 971          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 2010         |
# |    iterations           | 38           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0026976196 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.000819    |
# |    value_loss           | 12.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 1990         |
# |    iterations           | 39           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0042032953 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -9.23e-05    |
# |    value_loss           | 9.61         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 943         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 1976        |
# |    iterations           | 40          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.009946753 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.6        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000677   |
# |    value_loss           | 31.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 1966         |
# |    iterations           | 41           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0043414906 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.05         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000689    |
# |    value_loss           | 38.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 906          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 1956         |
# |    iterations           | 42           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0042591826 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.54         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 68.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 1937        |
# |    iterations           | 43          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.005954613 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.000968   |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 1923        |
# |    iterations           | 44          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.004912385 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.93        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | 7.4e-05     |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 927         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 1913        |
# |    iterations           | 45          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.006276274 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62        |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 8.67        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 935          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 1905         |
# |    iterations           | 46           |
# |    time_elapsed         | 395          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0032530888 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.65         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 35           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 1897        |
# |    iterations           | 47          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.003682674 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.11        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000292   |
# |    value_loss           | 7.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 48          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.007805405 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 4.57        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 986          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1882         |
# |    iterations           | 49           |
# |    time_elapsed         | 426          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0042917426 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.961       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000184    |
# |    value_loss           | 5.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 986          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 1875         |
# |    iterations           | 50           |
# |    time_elapsed         | 436          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0048729256 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.22         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 4.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 1870         |
# |    iterations           | 51           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0035774442 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.949       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.36         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000562    |
# |    value_loss           | 3.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 970          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1864         |
# |    iterations           | 52           |
# |    time_elapsed         | 456          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0029046398 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.8         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000472    |
# |    value_loss           | 31.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 1857        |
# |    iterations           | 53          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.004410941 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.07        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -1.31e-05   |
# |    value_loss           | 28.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 1852         |
# |    iterations           | 54           |
# |    time_elapsed         | 477          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0048009744 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.744        |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 0.00027      |
# |    value_loss           | 14.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 1848         |
# |    iterations           | 55           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0042376565 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000556    |
# |    value_loss           | 3.68         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 963        |
# |    ep_rew_mean          | 140        |
# | time/                   |            |
# |    fps                  | 1845       |
# |    iterations           | 56         |
# |    time_elapsed         | 497        |
# |    total_timesteps      | 917504     |
# | train/                  |            |
# |    approx_kl            | 0.00514975 |
# |    clip_fraction        | 0.0443     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.915     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.942      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00124   |
# |    value_loss           | 3.95       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 1842         |
# |    iterations           | 57           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0040037576 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | 0.000233     |
# |    value_loss           | 18.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 970          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 1836         |
# |    iterations           | 58           |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0036252802 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.000767    |
# |    value_loss           | 31.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 1833         |
# |    iterations           | 59           |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0034857006 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | 0.00034      |
# |    value_loss           | 3.65         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 1831         |
# |    iterations           | 60           |
# |    time_elapsed         | 536          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0034925132 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -9.21e-05    |
# |    value_loss           | 19.1         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 955       |
# |    ep_rew_mean          | 143       |
# | time/                   |           |
# |    fps                  | 1825      |
# |    iterations           | 61        |
# |    time_elapsed         | 547       |
# |    total_timesteps      | 999424    |
# | train/                  |           |
# |    approx_kl            | 0.0040466 |
# |    clip_fraction        | 0.0423    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.853    |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.06      |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.000876 |
# |    value_loss           | 3.04      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 970        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 1822       |
# |    iterations           | 62         |
# |    time_elapsed         | 557        |
# |    total_timesteps      | 1015808    |
# | train/                  |            |
# |    approx_kl            | 0.00450184 |
# |    clip_fraction        | 0.034      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.826     |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38       |
# |    n_updates            | 244        |
# |    policy_gradient_loss | 0.000153   |
# |    value_loss           | 20.9       |
# ----------------------------------------

# %% [markdown]
# ## Evaluate the agent 📈
# - Remember to wrap the environment in a [Monitor](https://stable-baselines3.readthedocs.io/en/master/common/monitor.html).
# - Now that our Lunar Lander agent is trained 🚀, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`.
# - To fill that part you need to [check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)
# - In the next step,  we'll see **how to automatically evaluate and share your agent to compete in a leaderboard, but for now let's do it ourselves**
#
#
# 💡 When you evaluate your agent, you should not use your training environment but create an evaluation environment.

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v3", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=250.99 +/- 14.339737757542165

# %%
from matplotlib import animation
from IPython.display import HTML

# Gera um vídeo do agente treinado no ambiente de avaliação
import matplotlib.pyplot as plt

frames = []
obs = eval_env.reset()[0]
done = False

while not done:
    # O modelo prevê a ação
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = eval_env.step(action)
    frame = eval_env.render()
    frames.append(frame)
    done = terminated or truncated

eval_env.close()

# Função para animar os frames
def display_video(frames):
    fig = plt.figure(figsize=(6, 6))
    plt.axis('off')
    im = plt.imshow(frames[0])

    def animate(i):
        im.set_array(frames[i])
        return [im]

    anim = animation.FuncAnimation(fig, animate, frames=len(frames), interval=50, blit=True)
    plt.close(fig)
    return HTML(anim.to_jshtml())

display_video(frames)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img79b4dfcfad8443809483724c0bd850b0">
#   <div class="anim-controls">
#     <input id="_anim_slider79b4dfcfad8443809483724c0bd850b0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim79b4dfcfad8443809483724c0bd850b0.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim79b4dfcfad8443809483724c0bd850b0.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim79b4dfcfad8443809483724c0bd850b0.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim79b4dfcfad8443809483724c0bd850b0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim79b4dfcfad8443809483724c0bd850b0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim79b4dfcfad8443809483724c0bd850b0.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim79b4dfcfad8443809483724c0bd850b0.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim79b4dfcfad8443809483724c0bd850b0.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim79b4dfcfad8443809483724c0bd850b0.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim79b4dfcfad8443809483724c0bd850b0.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select79b4dfcfad8443809483724c0bd850b0"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_79b4dfcfad8443809483724c0bd850b0"
#              >
#       <label for="_anim_radio1_79b4dfcfad8443809483724c0bd850b0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_79b4dfcfad8443809483724c0bd850b0"
#              checked>
#       <label for="_anim_radio2_79b4dfcfad8443809483724c0bd850b0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_79b4dfcfad8443809483724c0bd850b0"
#              >
#       <label for="_anim_radio3_79b4dfcfad8443809483724c0bd850b0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img79b4dfcfad8443809483724c0bd850b0";
#     var slider_id = "_anim_slider79b4dfcfad8443809483724c0bd850b0";
#     var loop_select_id = "_anim_loop_select79b4dfcfad8443809483724c0bd850b0";
#     var frames = new Array(366);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAIY1J

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! As you saw, the current agent is not doing great. As a first suggestion, you can train for more steps. With 1,000,000 steps, we saw some great results!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here are some ideas to achieve so:
# * Train more steps
# * Try different hyperparameters for `PPO`. You can see them at https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters.
# * Check the [Stable-Baselines3 documentation](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) and try another model such as DQN.
# * **Push your new trained model** on the Hub 🔥
#
# **Compare the results of your LunarLander-v2 with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆
#
# Is moon landing too boring for you? Try to **change the environment**, why not use MountainCar-v0, CartPole-v1 or CarRacing-v0? Check how they work [using the gym documentation](https://www.gymlibrary.dev/) and have fun 🎉.
